# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily', 'Frank', 'Gina', 'Saul', 'Paul', 'Nina'],
        'age': [25, 34, 18, 47, 29, 50, 27, 28, 33, 49],
        'gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'F'],
        'country': ['USA', 'Canada', 'USA', 'USA', 'Canada', 'USA', 'USA', 'USA', 'USA', 'Canada'],
        'salary': [50000, 65000, 35000, 80000, 45000, 70000, 55000, 45000, 70000, 85000],
        'department': ['Sales', 'Sales', 'Sales', 'Marketing', 'IT', 'Marketing', 'IT', 'Sales', 'Sales', 'Marketing'],
        'age_group': ["old", "old", "old", "old", "old", "old", "old", "old", "old", "old"],
        'age_range': [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
        'is_american': [True, False, True, False, True, True, True, True, True, True],
        'salary_rank': [4., 6., 1., 9., 2., 7., 5., 3., 8., 10.],
        'age_category': ['senior', 'senior', 'junior', 'senior', 'junior', 'senior', 'senior', 'junior', 'senior', 'senior'],
        'years_exp': [1, 1, 3, 8, 5, 2, 1, 2, 4, 7]
        }

df = pd.DataFrame(data)
df
# Out:
#       name  age gender country  salary department age_group  age_range  \
# 0    Alice   25      F     USA   50000      Sales       old        NaN
# 1      Bob   34      M  Canada   65000      Sales       old        NaN
# 2  Charlie   18      M     USA   35000      Sales       old        NaN
# 3    David   47      M     USA   80000  Marketing       old        NaN
# 4    Emily   29      F  Canada   45000         IT       old        NaN
# 5    Frank   50      M     USA   70000  Marketing       old        NaN
# 6     Gina   27      F     USA   55000         IT       old        NaN
# 7     Saul   28      M     USA   45000      Sales       old        NaN
# 8     Paul   33      M     USA   70000      Sales       old        NaN
# 9     Nina   49      F  Canada   85000  Marketing       old        NaN
#
#    is_american  salary_rank age_category  years_exp
# 0         True          4.0       senior          1
# 1        False          6.0       senior          1
# ...

# %%
# 1. Create a scatter plot with a linear regression line
sns.regplot(x='age', y='salary', data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 2. Create a scatter plot with a polynomial regression line
sns.regplot(x='age', y='salary', data=df, order=2)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 3. Create a scatter plot with a lowess regression line
sns.regplot(x='age', y='salary', data=df, lowess=True)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 4. Create a scatter plot with a different marker for each group
sns.scatterplot(x='age', y='salary', hue='department', style='department', data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 5. Create a scatter plot with different colors for each group and a legend
sns.scatterplot(x='age', y='salary', hue='department', palette='Set2', data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 6. Create a scatter plot with different marker sizes for each data point
sns.scatterplot(x='age', y='salary', size='years_exp', data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 7. Create a scatter plot matrix with histograms on the diagonal
sns.pairplot(df, diag_kind='hist')
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# 8. Create a scatter plot matrix with density curves on the diagonal
sns.pairplot(df, diag_kind='kde')

# %%
# 9. Create a scatter plot matrix with hexbin plots
sns.pairplot(df)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# 10. Create a box plot with separate colors for each group
sns.boxplot(x='department', y='salary', data=df, palette='Set2')
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 11. Create a violin plot with separate colors for each group
sns.violinplot(x='department', y='salary', data=df, palette='Set2')
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 12. Create a swarm plot with separate colors for each group
sns.swarmplot(x='department', y='salary', data=df, palette='Set2')
# Out:
# <ipython-input-13-7d231dfed38f>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='department', y='salary', data=df, palette='Set2')
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 13. Create a bar plot with separate colors for each group
sns.barplot(x='department', y='salary', data=df, palette='Set2')
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 14. Create a histogram with a density curve
sns.histplot(df['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# 15. Create a heatmap of the correlation matrix
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# 15. Create a facet grid of scatter plots with different marker colors for each group
g = sns.FacetGrid(df, col='department')
g.map(sns.scatterplot, 'age', 'salary')

# %%
# 16. Create a facet grid of histograms with different colors for each group
g = sns.FacetGrid(df, col='department')
g.map(sns.histplot, 'salary', color='b')

# %%
# 17. Create a facet grid of violin plots with different colors for each group
g = sns.FacetGrid(df, col='department')
g.map(sns.violinplot, 'salary', palette='Set2')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:712: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# 18. Create a facet grid of box plots with different colors for each group
g = sns.FacetGrid(df, col='department')
g.map(sns.boxplot, 'salary', palette='Set2')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:712: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# 19. Create a pair plot with different colors for each group
sns.pairplot(df, hue='department', palette='Set2')

# %%
# 20. Create a line plot with markers and different colors for each group
sns.lineplot(x='age', y='salary', hue='department', style='department', markers=True, data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 21. Create a line plot with error bars
sns.lineplot(x='age', y='salary', hue='department', ci='sd', data=df)
# Out:
# <ipython-input-23-172eed382b31>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x='age', y='salary', hue='department', ci='sd', data=df)
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 22. Create a line plot with a shaded confidence interval
sns.lineplot(x='age', y='salary', hue='department', ci='sd', err_style='band', data=df)
# Out:
# <ipython-input-24-b919661b6485>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x='age', y='salary', hue='department', ci='sd', err_style='band', data=df)
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 23. Create a strip plot with different colors for each group
sns.stripplot(x='department', y='salary', palette='Set2', data=df)
# Out:
# <ipython-input-25-2b777ab8df7f>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='department', y='salary', palette='Set2', data=df)
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 24. Create a swarm plot with a horizontal orientation
sns.swarmplot(x='salary', y='department', orient='h', data=df)
# Out:
# <Axes: xlabel='salary', ylabel='department'>

# %%
# 25. Create a count plot with different colors for each group
sns.countplot(x='department', hue='gender', palette='Set2', data=df)
# Out:
# <Axes: xlabel='department', ylabel='count'>

# %%
# 26. Create a bar plot with error bars
sns.barplot(x='department', y='salary', ci='sd', data=df)
# Out:
# <ipython-input-28-c2118a726aae>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='department', y='salary', ci='sd', data=df)
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 27. Create a horizontal bar plot with error bars
sns.barplot(x='salary', y='department', ci='sd', orient='h', data=df)
# Out:
# <ipython-input-29-01746e00ce72>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='salary', y='department', ci='sd', orient='h', data=df)
# <Axes: xlabel='salary', ylabel='department'>

# %%
# 28. Create a stacked bar plot
sns.barplot(x='department', y='salary', hue='gender', dodge=False, data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 29. Create a stacked area plot
sns.lineplot(x='age', y='salary', hue='gender', estimator='sum', ci=None, data=df)
# Out:
# <ipython-input-31-8d752fd5df41>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='age', y='salary', hue='gender', estimator='sum', ci=None, data=df)
# <Axes: xlabel='age', ylabel='salary'>

# %%
# 30. Create a scatter plot with marginal histograms
sns.jointplot(x='age', y='salary', kind='scatter', marginal_kws=dict(bins=20, rug=True), data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2214: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# 31. Create a scatter plot with marginal density curves
sns.jointplot(x='age', y='salary', kind='scatter', marginal_kws=dict(bins=20, rug=True), joint_kws=dict(marker='.'), data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2214: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# 32. Create a scatter plot with a hexbin color map
sns.jointplot(x='age', y='salary', kind='hex', data=df)

# %%
# 33. Create a scatter plot with a kernel density estimate
sns.jointplot(x='age', y='salary', kind='kde', data=df)

# %%
# 34. Create a catplot of a categorical variable with a numerical variable
sns.catplot(x='department', y='salary', kind='swarm', hue='gender', data=df)

# %%
# 35. Create a catplot of multiple categorical variables with a numerical variable
sns.catplot(x='department', y='salary', kind='boxen', col='gender', data=df)

# %%
# 36. Create a catplot of multiple categorical variables with two numerical variables
sns.catplot(x='department', y='salary', kind='box', col='gender', row='age_category', data=df)

# %%
# 37. Create a FacetGrid with a regression plot for each group
g = sns.FacetGrid(df, col='department', hue='gender')
g.map(sns.regplot, 'age', 'salary', ci=None, scatter_kws={'s': 20})

# %%
# 38. Create a FacetGrid with a density plot for each group
g = sns.FacetGrid(df, col='department', hue='gender')
g.map(sns.kdeplot, 'salary', shade=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# ...

# %%
# 39. Create a FacetGrid with a histogram for each group
g = sns.FacetGrid(df, col='department', hue='gender')
g.map(sns.histplot, 'age', bins=10, alpha=.5)

# %%
# 40. Create a FacetGrid with a bar plot for each group
g = sns.FacetGrid(df, col='department', hue='gender')
g.map(sns.barplot, 'department', 'salary', ci=None)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
# 41. Create a heatmap of the correlation matrix
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# 42. Create a clustermap of the correlation matrix
sns.clustermap(df.corr().fillna(0), cmap='coolwarm')

# %%
# 43. Create a pairplot with different markers for each group
sns.pairplot(df, hue='department', markers=['o', 's', 'D'])

# %%
# 44. Create a pairplot with a density estimate for each scatter plot
sns.pairplot(df, diag_kind='kde', kind='scatter')

# %%
# 45. Create a pairplot with a hexbin color map for each scatter plot
sns.pairplot(df, diag_kind='hist', kind='hex', palette='inferno')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
# 46. Create a violin plot with different colors for each group
sns.violinplot(x='department', y='salary', hue='gender', split=True, data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 47. Create a boxen plot with different colors for each group
sns.boxenplot(x='department', y='salary', hue='gender', data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 48. Create a point plot with different colors for each group
sns.pointplot(x='department', y='salary', hue='gender', dodge=True, markers=['o', 's'], linestyles=['-', '--'], data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 49. Create a boxen plot with different colors for each age group
sns.boxenplot(x='department', y='salary', hue='age_group', data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>

# %%
# 50. Create a boxen plot with different colors for each group
sns.boxenplot(x='department', y='salary', hue='is_american', data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>
